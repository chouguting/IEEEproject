# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Mar 29 13:26:04 2019

@author: yu-hao
"""
import random
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, Lambda
from tensorflow.keras.layers import Activation
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
import numpy
import pandas as pd
from sklearn.metrics import precision_recall_curve
from sklearn import preprocessing
from sklearn import svm, metrics
#numpy.random.seed(10)
import sys
import all_22277_list
SAME_SYMPTOMS = 1
DIFF_SYMPTOMS = 0
POSITIVE = 1
NEGATIVE = 0
is_suv = 2



#366*22279
all_df = pd.read_csv("rma_H1N1_leave_001_out.csv",sep='\t',encoding='utf-8')

#11*22279
standar_df = pd.read_csv("H1N1_health_no_001.txt",sep='\t',encoding='utf-8')

#16*22279
test_df = pd.read_csv("rma_H1N1_001.txt",sep='\t',encoding='utf-8')

#北個DATA代表的意思(Title)
cols = all_22277_list.cols
#print((cols))



#把DATA利用cols當作列來排好
all_df=all_df[cols]
standar_df = standar_df[cols]
test_df=test_df[cols]



#生成366個(all_df的樣本數) 隨機數字 並且取<0.8的作為True ,其他是false
msk = numpy.random.rand(len(all_df)) < 0.8
#train_df = all_df[160:]
#test_df = all_df[:16]

#從剛才的msk中 True的編號從all_df中提取當作訓練用(大約8成)，其餘用來測試用
train_df = all_df[msk]
val_df = all_df[~msk]



'''print('total:',len(all_df),
      'train:',len(train_df),
      'val:',len(val_df),
      'test:',len(test_df))'''



def PreprocessData(raw_df):

    df=raw_df.drop(['ID'], axis=1)#移除name欄位
    ndarray = df.values#dataframe轉換為array
    Features = ndarray[:,1:]
    Label = ndarray[:,0]

    minmax_scale = preprocessing.MinMaxScaler(feature_range=(0, 1))
    scaledFeatures=minmax_scale.fit_transform(Features)

    return scaledFeatures,Label



train_Features,train_Label=PreprocessData(train_df)
#print(len(train_Features))
val_Features,val_Label=PreprocessData(val_df)
test_Features,test_Label=PreprocessData(test_df)
standar_Features,standar_Label=PreprocessData(standar_df)



#歐式距離
def euclid_dis(vects):
    x,y = vects
    sum_square = K.sum(K.square(x-y), axis=1, keepdims=True)
    return K.sqrt(K.maximum(sum_square, K.epsilon()))



def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)



#loss
def contrastive_loss(y_true, y_pred):
    margin = 1
    square_pred = K.square(y_pred)
    margin_square = K.square(K.maximum(margin - y_pred, 0))
    return K.mean(y_true * square_pred + (1 - y_true) * margin_square)



def create_pairs(x, train_symptoms):
    n=min([len(train_symptoms[NEGATIVE]),len(train_symptoms[POSITIVE])])
    random_pairs = []
    random_labels = []
    negative_negative_pairs = []
    negative_positive_pairs = []
    positive_positive_pairs = []
    positive_negative_pairs = []
    negative_negative_pairs = create_negative_negative_pairs(x, train_symptoms)
    negative_positive_pairs = create_negative_positive_pairs(x, train_symptoms)
    positive_positive_pairs = create_positive_positive_pairs(x, train_symptoms)
    positive_negative_pairs = create_positive_negative_pairs(x, train_symptoms)
    for i in range(n*n//4):
        random_pairs += [negative_negative_pairs[i],negative_positive_pairs[i]]
        random_labels += [SAME_SYMPTOMS,DIFF_SYMPTOMS]
        random_pairs += [positive_positive_pairs[i],positive_negative_pairs[i]]
        random_labels += [SAME_SYMPTOMS,DIFF_SYMPTOMS]
    #print(numpy.array(random_pairs).shape)
    #print(numpy.array(random_labels).shape)
    return numpy.array(random_pairs), numpy.array(random_labels)



def create_negative_negative_pairs(x, train_symptoms):
    negative_negative_pairs = []
    random_negative_negative_pairs = []
    n=min([len(train_symptoms[NEGATIVE]),len(train_symptoms[POSITIVE])])
    for i in range(len(train_symptoms[NEGATIVE])):
        for j in range(len(train_symptoms[NEGATIVE])):
            z1, z2 = train_symptoms[NEGATIVE][i], train_symptoms[NEGATIVE][j]
            negative_negative_pairs += [[x[z1], x[z2]]]
    #print("negative_negative_pairs:",len(negative_negative_pairs))
    negative_negative_pairs_index = random.sample(range(0,len(negative_negative_pairs)), n*n//4)
    for i in range(len(negative_negative_pairs_index)):
        random_negative_negative_pairs += [negative_negative_pairs[negative_negative_pairs_index[i]]]
    #print("negative_negative_pairs_index:",len(negative_negative_pairs_index))
    #print("random_negative_negative_pairs:",len(random_negative_negative_pairs))
    return random_negative_negative_pairs



def create_negative_positive_pairs(x, train_symptoms):
    negative_positive_pairs = []
    random_negative_positive_pairs = []
    k = 0
    n=min([len(train_symptoms[NEGATIVE]),len(train_symptoms[POSITIVE])])
    for i in range(len(train_symptoms[NEGATIVE])):
        for j in range(len(train_symptoms[NEGATIVE])):
            if(k < len(train_symptoms[POSITIVE])):
                z1, z2 = train_symptoms[NEGATIVE][i], train_symptoms[POSITIVE][k]
                negative_positive_pairs += [[x[z1], x[z2]]]
                k += 1
            else:
                k = 0
                z1, z2 = train_symptoms[NEGATIVE][i], train_symptoms[POSITIVE][k]
                negative_positive_pairs += [[x[z1], x[z2]]]
    #print("negative_positive_pairs:",len(negative_positive_pairs))
    negative_positive_pairs_index = random.sample(range(0,len(negative_positive_pairs)), n*n//4)
    for i in range(len(negative_positive_pairs_index)):
        random_negative_positive_pairs += [negative_positive_pairs[negative_positive_pairs_index[i]]]
    #print("negative_positive_pairs_index:",len(negative_positive_pairs_index))
    #print("random_negative_positive_pairs:",len(random_negative_positive_pairs))
    return random_negative_positive_pairs



def create_positive_positive_pairs(x, train_symptoms):
    positive_positive_pairs = []
    random_positive_positive_pairs = []
    n=min([len(train_symptoms[NEGATIVE]),len(train_symptoms[POSITIVE])])
    for i in range(len(train_symptoms[POSITIVE])):
        for j in range(len(train_symptoms[POSITIVE])):
            z1, z2 = train_symptoms[POSITIVE][i], train_symptoms[POSITIVE][j]
            positive_positive_pairs += [[x[z1], x[z2]]]
    #print("positive_positive_pairs:",len(positive_positive_pairs))
    positive_positive_pairs_index = random.sample(range(0,len(positive_positive_pairs)), n*n//4)
    for i in range(len(positive_positive_pairs_index)):
        random_positive_positive_pairs += [positive_positive_pairs[positive_positive_pairs_index[i]]]
    #print("positive_positive_pairs_index:",len(positive_positive_pairs_index))
    #print("random_positive_positive_pairs:",len(random_positive_positive_pairs))
    return random_positive_positive_pairs



def create_positive_negative_pairs(x, train_symptoms):
    positive_negative_pairs = []
    random_positive_negative_pairs = []
    k = 0
    n=min([len(train_symptoms[NEGATIVE]),len(train_symptoms[POSITIVE])])
    for i in range(len(train_symptoms[POSITIVE])):
        for j in range(len(train_symptoms[POSITIVE])):
            if(k < len(train_symptoms[NEGATIVE])):
                z1, z2 = train_symptoms[POSITIVE][i], train_symptoms[NEGATIVE][k]
                positive_negative_pairs += [[x[z1], x[z2]]]
                k += 1
            else:
                k = 0
                z1, z2 = train_symptoms[POSITIVE][i], train_symptoms[NEGATIVE][k]
                positive_negative_pairs += [[x[z1], x[z2]]]
                k = 0
    #print("positive_negative_pairs:",len(positive_negative_pairs))
    positive_negative_pairs_index = random.sample(range(0,len(positive_negative_pairs)), n*n//4)
    for i in range(len(positive_negative_pairs_index)):
        random_positive_negative_pairs += [positive_negative_pairs[positive_negative_pairs_index[i]]]
    #print("positive_negative_pairs_index:",len(positive_negative_pairs_index))
    #print("random_positive_negative_pairs:",len(random_positive_negative_pairs))
    return random_positive_negative_pairs
'''
def create_pairs(x, train_symptoms):
    pairs = []
    labels = []
    random_pairs = []
    random_labels = []
    n=min([len(train_symptoms[NEGATIVE]),len(train_symptoms[POSITIVE])])
    final_label0_index = len(train_symptoms[NEGATIVE])*len(train_symptoms[NEGATIVE])*2
    k = 0
    print('n:',n)
    for i in range(len(train_symptoms[NEGATIVE])):
        for j in range(len(train_symptoms[NEGATIVE])):
            z1, z2 = train_symptoms[NEGATIVE][i], train_symptoms[NEGATIVE][j]
            pairs += [[x[z1], x[z2]]]
            if(k < len(train_symptoms[POSITIVE])):
                z1, z2 = train_symptoms[NEGATIVE][i], train_symptoms[POSITIVE][k]
                pairs += [[x[z1], x[z2]]]
                k += 1
            else:
                k = 0
                z1, z2 = train_symptoms[NEGATIVE][i], train_symptoms[POSITIVE][k]
                pairs += [[x[z1], x[z2]]]
            labels += [SAME_SYMPTOMS,DIFF_SYMPTOMS]
    k = 0
    for i in range(len(train_symptoms[POSITIVE])):
        for j in range(len(train_symptoms[POSITIVE])):
            z1, z2 = train_symptoms[POSITIVE][i], train_symptoms[POSITIVE][j]
            pairs += [[x[z1], x[z2]]]
            if(k < len(train_symptoms[NEGATIVE])):
                z1, z2 = train_symptoms[POSITIVE][i], train_symptoms[NEGATIVE][k]
                pairs += [[x[z1], x[z2]]]
                k += 1
            else:
                k = 0
                z1, z2 = train_symptoms[POSITIVE][i], train_symptoms[NEGATIVE][k]
                pairs += [[x[z1], x[z2]]]
            labels += [SAME_SYMPTOMS,DIFF_SYMPTOMS]
    print("pairs:",len(pairs),"labels:",len(labels))
    zero_zero_pair_index = random.sample(range(0,final_label0_index,2), n*n)
    zero_one_pair_index = random.sample(range(1,final_label0_index,2), n*n)
    one_one_pair_index = random.sample(range(final_label0_index,len(pairs),2), n*n)
    one_zero_pair_index = random.sample(range(final_label0_index+1,len(pairs),2), n*n)
    for i in range(n*n//8):
        random_pairs += [pairs[zero_zero_pair_index[i]],pairs[zero_one_pair_index[i]]]
        random_labels += [SAME_SYMPTOMS,DIFF_SYMPTOMS]
        random_pairs += [pairs[one_one_pair_index[i]],pairs[one_zero_pair_index[i]]]
        random_labels += [SAME_SYMPTOMS,DIFF_SYMPTOMS]
    print("zero_zero_pair_index:",len(zero_zero_pair_index))
    print("zero_one_pair_index:",len(zero_one_pair_index))
    print("one_one_pair_index:",len(one_one_pair_index))
    print("one_zero_pair_index:",len(one_zero_pair_index))
    print("random_labels:",len(random_labels))
    print(numpy.array(pairs).shape)
    print(numpy.array(random_pairs).shape)
    return numpy.array(random_pairs), numpy.array(random_labels)
'''
# Out:
# '\ndef create_pairs(x, train_symptoms):\n    pairs = []\n    labels = []\n    random_pairs = []\n    random_labels = []\n    n=min([len(train_symptoms[NEGATIVE]),len(train_symptoms[POSITIVE])])\n    final_label0_index = len(train_symptoms[NEGATIVE])*len(train_symptoms[NEGATIVE])*2\n    k = 0\n    print(\'n:\',n)\n    for i in range(len(train_symptoms[NEGATIVE])):\n        for j in range(len(train_symptoms[NEGATIVE])):\n            z1, z2 = train_symptoms[NEGATIVE][i], train_symptoms[NEGATIVE][j]\n            pairs += [[x[z1], x[z2]]]\n            if(k < len(train_symptoms[POSITIVE])):\n                z1, z2 = train_symptoms[NEGATIVE][i], train_symptoms[POSITIVE][k]\n                pairs += [[x[z1], x[z2]]]\n                k += 1\n            else:\n                k = 0\n                z1, z2 = train_symptoms[NEGATIVE][i], train_symptoms[POSITIVE][k]\n                pairs += [[x[z1], x[z2]]]\n            labels += [SAME_SYMPTOMS,DIFF_SYMPTOMS]\n    k = 0\n    for i in range(len(train_symptoms[POSITIVE])):\n        for j in range(len(train_symptoms[POSITIVE])):\n            z1, z2 = train_symptoms[POSITIVE][i], train_symptoms[POSITIVE][j]\n            pairs += [[x[z1], x[z2]]]\n            if(k < len(train_symptoms[NEGATIVE])):\n                z1, z2 = train_symptoms[POSITIVE][i], train_symptoms[NEGATIVE][k]\n                pairs += [[x[z1], x[z2]]]\n                k += 1\n            else:\n                k = 0\n                z1, z2 = train_symptoms[POSITIVE][i], train_symptoms[NEGATIVE][k]\n                pairs += [[x[z1], x[z2]]]\n            labels += [SAME_SYMPTOMS,DIFF_SYMPTOMS]\n    print("pairs:",len(pairs),"labels:",len(labels))\n    zero_zero_pair_index = random.sample(range(0,final_label0_index,2), n*n)\n    zero_one_pair_index = random.sample(range(1,final_label0_index,2), n*n)\n    one_one_pair_index = random.sample(range(final_label0_index,len(pairs),2), n*n)\n    one_zero_pair_index = random.sample(range(final_label0_index+1,len(pairs),2), n*n)\n    for i in range(n*n//8):\n        random_pairs += [pairs[zero_zero_pair_index[i]],pairs[zero_one_pair_index[i]]]\n        random_labels += [SAME_SYMPTOMS,DIFF_SYMPTOMS]\n        random_pairs += [pairs[one_one_pair_index[i]],pairs[one_zero_pair_index[i]]]\n        random_labels += [SAME_SYMPTOMS,DIFF_SYMPTOMS]\n    print("zero_zero_pair_index:",len(zero_zero_pair_index))\n    print("zero_one_pair_index:",len(zero_one_pair_index))\n    print("one_one_pair_index:",len(one_one_pair_index))\n    print("one_zero_pair_index:",len(one_zero_pair_index))\n    print("random_labels:",len(random_labels))\n    print(numpy.array(pairs).shape)\n    print(numpy.array(random_pairs).shape)\n    return numpy.array(random_pairs), numpy.array(random_labels)\n'

# %%
def create_test_pairs(x, train_symptoms, y, test_symptoms):

    '''Positive and negative pair creation.
    Alternates between positive and negative pairs.
    '''
    positive_random_index = []
    negative_random_index = []
    test_pairs = []
    test_labels = []
    if(len(test_symptoms[NEGATIVE])>0):
        positive_random_index = random.sample(range(0,len(train_symptoms[POSITIVE])), len(test_symptoms[NEGATIVE]))
        negative_random_index = random.sample(range(0,len(train_symptoms[NEGATIVE])), len(test_symptoms[NEGATIVE]))
        #print('positive_random_index:',positive_random_index)
        #print('negative_random_index:',negative_random_index)
        for i in range(len(test_symptoms[NEGATIVE])):
                z1, z2 = test_symptoms[NEGATIVE][i], train_symptoms[NEGATIVE][negative_random_index[i]]
                test_pairs += [[y[z1], x[z2]]]
                z1, z2 = test_symptoms[NEGATIVE][i], train_symptoms[POSITIVE][positive_random_index[i]]
                test_pairs += [[y[z1], x[z2]]]
                test_labels += [SAME_SYMPTOMS,DIFF_SYMPTOMS]
    if(len(test_symptoms[NEGATIVE])>0):
        positive_random_index = random.sample(range(0,len(train_symptoms[POSITIVE])), len(test_symptoms[NEGATIVE]))
        negative_random_index = random.sample(range(0,len(train_symptoms[NEGATIVE])), len(test_symptoms[NEGATIVE]))
        #print('positive_random_index:',positive_random_index)
        #print('negative_random_index:',negative_random_index)
        for i in range(len(test_symptoms[NEGATIVE])):
                z1, z2 = train_symptoms[NEGATIVE][negative_random_index[i]], test_symptoms[NEGATIVE][i]
                test_pairs += [[x[z1], y[z2]]]
                z1, z2 = train_symptoms[POSITIVE][positive_random_index[i]], test_symptoms[NEGATIVE][i]
                test_pairs += [[x[z1], y[z2]]]
                test_labels += [SAME_SYMPTOMS,DIFF_SYMPTOMS]
    if(len(test_symptoms[POSITIVE])>0):
        positive_random_index = random.sample(range(0,len(train_symptoms[POSITIVE])), len(test_symptoms[POSITIVE]))
        negative_random_index = random.sample(range(0,len(train_symptoms[NEGATIVE])), len(test_symptoms[POSITIVE]))
        #print('positive_random_index:',positive_random_index)
        #print('negative_random_index:',negative_random_index)
        for i in range(len(test_symptoms[POSITIVE])):
                z1, z2 = test_symptoms[POSITIVE][i], train_symptoms[POSITIVE][positive_random_index[i]]
                test_pairs += [[y[z1], x[z2]]]
                z1, z2 = test_symptoms[POSITIVE][i], train_symptoms[NEGATIVE][negative_random_index[i]]
                test_pairs += [[y[z1], x[z2]]]
                test_labels += [SAME_SYMPTOMS,DIFF_SYMPTOMS]
    if(len(test_symptoms[POSITIVE])>0):
        positive_random_index = random.sample(range(0,len(train_symptoms[POSITIVE])), len(test_symptoms[POSITIVE]))
        negative_random_index = random.sample(range(0,len(train_symptoms[NEGATIVE])), len(test_symptoms[POSITIVE]))
        #print('positive_random_index:',positive_random_index)
        #print('negative_random_index:',negative_random_index)
        for i in range(len(test_symptoms[POSITIVE])):
                z1, z2 = train_symptoms[POSITIVE][positive_random_index[i]], test_symptoms[POSITIVE][i]
                test_pairs += [[x[z1], y[z2]]]
                z1, z2 = train_symptoms[NEGATIVE][negative_random_index[i]], test_symptoms[POSITIVE][i]
                test_pairs += [[x[z1], y[z2]]]
                test_labels += [SAME_SYMPTOMS,DIFF_SYMPTOMS]
    #print('len(test_pairs):',len(test_pairs))
    #print(numpy.array(test_pairs).shape)
    return numpy.array(test_pairs), numpy.array(test_labels)



def create_standar_test_pairs(x, standar_symptoms, y, test_symptoms):

    '''Positive and negative pair creation.
    Alternates between positive and negative pairs.
    '''
    test_pairs = []
    test_labels = []
    if(len(test_symptoms[NEGATIVE])>0):
        for i in range(len(standar_symptoms[NEGATIVE])):
            for j in range(len(test_symptoms[NEGATIVE])):
                z1, z2 = standar_symptoms[NEGATIVE][i], test_symptoms[NEGATIVE][j]
                test_pairs += [[x[z1], y[z2]]]
                test_labels += [SAME_SYMPTOMS]
    if(len(test_symptoms[POSITIVE])>0):
        for i in range(len(standar_symptoms[NEGATIVE])):
            for j in range(len(test_symptoms[POSITIVE])):
                z1, z2 = standar_symptoms[NEGATIVE][i], test_symptoms[POSITIVE][j]
                test_pairs += [[x[z1], y[z2]]]
                test_labels += [DIFF_SYMPTOMS]

    #print('len(test_pairs):',len(test_pairs))
    #print(numpy.array(test_pairs).shape)
    return numpy.array(test_pairs), numpy.array(test_labels)



def create_base_net(input_shape):
    '''
    input = Input(shape = input_shape)
   #x = Flatten()(input)
#####################################################
    x = Dense(100, activation='relu')(input)
    x = Dropout(0.1)(x)
    #x = Dropout(0.2)(x)
    x = Dense(100, activation='relu')(x)
    #x = Dropout(0.1)(x)
    x = Dense(100, activation='relu')(x)
    #x = Dropout(0.2)(x)
    x = Dense(100, activation='relu')(x)
    #x = Dense(50, activation='relu')(x)
    x = Dense(1, activation='sigmoid')(x)
    model = Model(input, x)
    '''
    #model.summary()
    model = Sequential()
    model.add(Dense(units=100, input_dim=22277, kernel_initializer='uniform', activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(units=100, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(units=100, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(units=100, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))
    return model



def compute_accuracy(y_true, y_pred):
    '''Compute classification accuracy with a fixed threshold on distances.
    '''
    pred = y_pred.ravel() < 0.5
    return numpy.mean(pred == y_true)



def accuracy(y_true, y_pred):
    '''Compute classification accuracy with a fixed threshold on distances.
    '''
    return K.mean(K.equal(y_true, K.cast(y_pred < 0.5, y_true.dtype)))

# %%
# the data, split between train and test sets
input_shape = train_Features.shape[1:]
#print(input_shape[0])
standar_symptoms = [numpy.where(standar_Label == i)[0] for i in range(is_suv)]
# create training+test positive and negative pairs
train_symptoms = [numpy.where(train_Label == i)[0] for i in range(is_suv)]
a = [numpy.where(train_Label == 0)[0],numpy.where(train_Label == 1)[0]]
#print("len(a[0]),len(a[1])",len(a[0]),len(a[1]))
#print(len(train_symptoms[0]),len(train_symptoms[1]))
train_pairs, train_y = create_pairs(train_Features, train_symptoms)
#print("len(train_pairs),len(train_y)",len(train_pairs),len(train_y))
#plot_images_labels_prediction(x_train[0])
val_symptoms = [numpy.where(val_Label == i)[0] for i in range(is_suv)]
val_pairs, val_y = create_test_pairs(train_Features, train_symptoms, val_Features, val_symptoms)
#print("len(val_pairs),len(val_y)",len(val_pairs),len(val_y))

test_symptoms = [numpy.where(test_Label == i)[0] for i in range(is_suv)]
test_pairs, test_y = create_standar_test_pairs(standar_Features, standar_symptoms, test_Features, test_symptoms)
#print("len(test_pairs),len(test_y)",len(test_pairs),len(test_y))
# network definition
base_network = create_base_net(input_shape)
base_network.save("base_network.h5")
input_a = Input(shape=input_shape)
input_b = Input(shape=input_shape)
# because we re-use the same instance `base_network`,
# the weights of the network
# will be shared across the two branches

# %%
#TODO: WHAT IS THIS???
#??????????????????
processed_a = base_network(input_a)
processed_b = base_network(input_b)



print(type(base_network))
print(type(input_a))

distance = Lambda(euclid_dis,
                  output_shape=eucl_dist_output_shape)([processed_a, processed_b])

print(type(processed_a))
# Out:
# <class 'tensorflow.python.keras.engine.sequential.Sequential'>
# <class 'tensorflow.python.keras.engine.keras_tensor.KerasTensor'>
# <class 'tensorflow.python.keras.engine.keras_tensor.KerasTensor'>

# %%
#跑20次
for times in range(20):
    model = Model([input_a, input_b], distance)
    #print("start")
    import tensorflow.keras
    rms = RMSprop()
    opt = tensorflow.keras.optimizers.Adam(lr=0.00001)
    model.save("H1N1 leave_one_out.h5")



    model.compile(loss=contrastive_loss, optimizer=opt, metrics=[accuracy])
    train_history = model.fit([train_pairs[:, 0], train_pairs[:, 1]], tf.cast(train_y,tf.float32),
              batch_size=200,
              epochs=25,
              validation_data=([val_pairs[:, 0], val_pairs[:, 1]], tf.cast(val_y,tf.float32)))




    # compute final accuracy on training and test sets
    y_pred_train = model.predict([train_pairs[:, 0], train_pairs[:, 1]])
    train_acc = compute_accuracy(train_y, y_pred_train)
    y_pred_val = model.predict([val_pairs[:, 0], val_pairs[:, 1]])
    val_acc = compute_accuracy(val_y, y_pred_val)
    test_pred = []
    y_pred_test = model.predict([test_pairs[:, 0], test_pairs[:, 1]])
    test_acc = compute_accuracy(test_y, y_pred_test)
    for i in y_pred_test:
        if(i > 0.5):
            #print(i)
            test_pred.append(0)
        else:
            #print(i)
            test_pred.append(1)


    #roc
    #fpr, tpr, thresholds = metrics.roc_curve(test_y, y_pred_test, pos_label=0)
    #print("fpr:",fpr)
    #print("tpr:",tpr)
    #auc_roc = metrics.auc(fpr, tpr)
    #pr
    #precision, recall, thresholds = precision_recall_curve(test_y, y_pred_test, pos_label=0)
    #auc_pr = metrics.auc(recall, precision)

    test_TP=0
    test_TN=0
    test_FP=0
    test_FN=0
    #print(test_pred)
    #print(test_y)
    for j in range(len(test_pred)):
        if(test_pred[j]==SAME_SYMPTOMS and test_pred[j]==test_y[j]):
            test_TP=test_TP+1
        else:
            test_TP=test_TP+0

        if(test_pred[j]==DIFF_SYMPTOMS and test_pred[j]==test_y[j]):
            test_TN=test_TN+1
        else:
            test_TN=test_TN+0

        if(test_y[j]==DIFF_SYMPTOMS and test_pred[j]==SAME_SYMPTOMS):
            test_FP=test_FP+1
        else:
            test_FP=test_FP+0

        if(test_y[j]==SAME_SYMPTOMS and test_pred[j]==DIFF_SYMPTOMS):
            test_FN=test_FN+1
        else:
            test_FN=test_FN+0
    print("test_TP:",test_TP)
    print("test_TN:",test_TN)
    print("test_FP:",test_FP)
    print("test_FN:",test_FN)

    print('* Accuracy on training set: %0.2f%%' % (100 * train_acc))
    print('* Accuracy on validation set: %0.2f%%' % (100 * val_acc))
    print('* Accuracy on test set: %0.2f%%' % (100 * test_acc))
    print("==========================================\n\n")



    if(times==0):
        with open("H1N1_result.txt", 'w', newline='') as f:
            writer = f.write("Iteration:"+str(times)+"\n" )
            writer = f.write("TP:%d\n" % test_TP)
            writer = f.write("TN:%d\n" % test_TN)
            writer = f.write("FP:%d\n" % test_FP)
            writer = f.write("FN:%d\n" % test_FN)
        #    writer = f.write("auc(pr):%0.2f\n" % auc_pr)
        #    writer = f.write("auc(roc):%0.2f\n" % auc_roc)
            writer = f.write('* Accuracy on training set: %0.2f%%' % (100 * train_acc))
            writer = f.write('* Accuracy on validation set: %0.2f%%' % (100 * val_acc))
            writer = f.write('* Accuracy on test set: %0.2f%%' % (100 * test_acc))
            writer = f.write('\n======================================================\n\n')
    else:
        with open("H1N1_result.txt", 'a', newline='') as f:
            writer = f.write("Iteration:"+str(times)+"\n" )
            writer = f.write("TP:%d\n" % test_TP)
            writer = f.write("TN:%d\n" % test_TN)
            writer = f.write("FP:%d\n" % test_FP)
            writer = f.write("FN:%d\n" % test_FN)
        #    writer = f.write("auc(pr):%0.2f\n" % auc_pr)
        #    writer = f.write("auc(roc):%0.2f\n" % auc_roc)
            writer = f.write('* Accuracy on training set: %0.2f%%' % (100 * train_acc))
            writer = f.write('* Accuracy on validation set: %0.2f%%' % (100 * val_acc))
            writer = f.write('* Accuracy on test set: %0.2f%%' % (100 * test_acc))
            writer = f.write('\n======================================================\n\n')
# Out:
# Epoch 1/25
# 96/96 [==============================] - 6s 40ms/step - loss: 0.5011 - accuracy: 0.4954 - val_loss: 0.4778 - val_accuracy: 0.5000
# Epoch 2/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.4675 - accuracy: 0.5003 - val_loss: 0.4145 - val_accuracy: 0.5000
# Epoch 3/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.4096 - accuracy: 0.5042 - val_loss: 0.3796 - val_accuracy: 0.5000
# Epoch 4/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.3836 - accuracy: 0.5009 - val_loss: 0.3474 - val_accuracy: 0.5000
# Epoch 5/25
# 96/96 [==============================] - 2s 26ms/step - loss: 0.3525 - accuracy: 0.4983 - val_loss: 0.3157 - val_accuracy: 0.5000
# Epoch 6/25
# 96/96 [==============================] - 2s 26ms/step - loss: 0.3278 - accuracy: 0.5306 - val_loss: 0.2975 - val_accuracy: 0.5947
# Epoch 7/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.3138 - accuracy: 0.5652 - val_loss: 0.2807 - val_accuracy: 0.6358
# Epoch 8/25
# 96/96 [==============================] - 2s 26ms/step - loss: 0.2979 - accuracy: 0.5792 - val_loss: 0.2681 - val_accuracy: 0.6605
# Epoch 9/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.2845 - accuracy: 0.5887 - val_loss: 0.2520 - val_accuracy: 0.6637
# Epoch 10/25
# 96/96 [==============================] - 3s 26ms/step - loss: 0.2782 - accuracy: 0.5919 - val_loss: 0.2367 - val_accuracy: 0.6644
# Epoch 11/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.2684 - accuracy: 0.6024 - val_loss: 0.2242 - val_accuracy: 0.6626
# Epoch 12/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.2494 - accuracy: 0.6338 - val_loss: 0.2140 - val_accuracy: 0.6683
# Epoch 13/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.2402 - accuracy: 0.6477 - val_loss: 0.2018 - val_accuracy: 0.7041
# Epoch 14/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.2260 - accuracy: 0.6700 - val_loss: 0.1972 - val_accuracy: 0.6969
# Epoch 15/25
# 96/96 [==============================] - 2s 26ms/step - loss: 0.2173 - accuracy: 0.6866 - val_loss: 0.1847 - val_accuracy: 0.7328
# Epoch 16/25
# 96/96 [==============================] - 2s 26ms/step - loss: 0.1990 - accuracy: 0.7157 - val_loss: 0.1752 - val_accuracy: 0.7471
# Epoch 17/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.1820 - accuracy: 0.7415 - val_loss: 0.1667 - val_accuracy: 0.7725
# Epoch 18/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.1680 - accuracy: 0.7668 - val_loss: 0.1676 - val_accuracy: 0.7337
# Epoch 19/25
# 96/96 [==============================] - 2s 26ms/step - loss: 0.1510 - accuracy: 0.7982 - val_loss: 0.1628 - val_accuracy: 0.7444
# Epoch 20/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.1344 - accuracy: 0.8203 - val_loss: 0.1692 - val_accuracy: 0.7580
# Epoch 21/25
# 96/96 [==============================] - 3s 26ms/step - loss: 0.1125 - accuracy: 0.8549 - val_loss: 0.1524 - val_accuracy: 0.7655
# Epoch 22/25
# 96/96 [==============================] - 3s 26ms/step - loss: 0.0968 - accuracy: 0.8823 - val_loss: 0.1514 - val_accuracy: 0.7798
# Epoch 23/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.0775 - accuracy: 0.9127 - val_loss: 0.1539 - val_accuracy: 0.7730
# Epoch 24/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.0664 - accuracy: 0.9266 - val_loss: 0.1614 - val_accuracy: 0.7637
# Epoch 25/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.0543 - accuracy: 0.9478 - val_loss: 0.1590 - val_accuracy: 0.7773
# test_TP: 100
# test_TN: 0
# test_FP: 0
# test_FN: 76
# * Accuracy on training set: 96.97%
# * Accuracy on validation set: 80.06%
# * Accuracy on test set: 56.82%
# ==========================================
#
#
# Epoch 1/25
#  - ETA: 1s - loss: 0.0479 - accuracy: 0.9565
# Epoch 2/25
# 96/96 [==============================] - 3s 28ms/step - loss: 0.0390 - accuracy: 0.9658 - val_loss: 0.1573 - val_accuracy: 0.7755
# Epoch 3/25
# 96/96 [==============================] - 3s 29ms/step - loss: 0.0336 - accuracy: 0.9696 - val_loss: 0.1451 - val_accuracy: 0.7959
# Epoch 4/25
# 96/96 [==============================] - 3s 29ms/step - loss: 0.0276 - accuracy: 0.9760 - val_loss: 0.1450 - val_accuracy: 0.7959
# Epoch 5/25
# 96/96 [==============================] - 3s 29ms/step - loss: 0.0249 - accuracy: 0.9778 - val_loss: 0.1470 - val_accuracy: 0.7923
# Epoch 6/25
# 96/96 [==============================] - 3s 28ms/step - loss: 0.0211 - accuracy: 0.9841 - val_loss: 0.1525 - val_accuracy: 0.7880
# Epoch 7/25
# 96/96 [==============================] - 3s 28ms/step - loss: 0.0195 - accuracy: 0.9846 - val_loss: 0.1646 - val_accuracy: 0.7590
# Epoch 8/25
# 96/96 [==============================] - 3s 28ms/step - loss: 0.0168 - accuracy: 0.9869 - val_loss: 0.1580 - val_accuracy: 0.7615
# Epoch 9/25
# 96/96 [==============================] - 3s 26ms/step - loss: 0.0158 - accuracy: 0.9858 - val_loss: 0.1569 - val_accuracy: 0.7701
# Epoch 10/25
#  - ETA: 0s - loss: 0.0136 - accuracy: 0.9866
# Epoch 11/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0097 - accuracy: 0.9931 - val_loss: 0.1521 - val_accuracy: 0.7862
# Epoch 12/25
# 96/96 [==============================] - 3s 30ms/step - loss: 0.0089 - accuracy: 0.9936 - val_loss: 0.1582 - val_accuracy: 0.7597
# Epoch 13/25
# 96/96 [==============================] - 3s 28ms/step - loss: 0.0087 - accuracy: 0.9932 - val_loss: 0.1568 - val_accuracy: 0.7597
# Epoch 14/25
# 96/96 [==============================] - 3s 28ms/step - loss: 0.0075 - accuracy: 0.9939 - val_loss: 0.1574 - val_accuracy: 0.7597
# Epoch 15/25
# 96/96 [==============================] - 3s 28ms/step - loss: 0.0075 - accuracy: 0.9937 - val_loss: 0.1593 - val_accuracy: 0.7597
# Epoch 16/25
# 96/96 [==============================] - 3s 28ms/step - loss: 0.0078 - accuracy: 0.9932 - val_loss: 0.1641 - val_accuracy: 0.7460
# Epoch 17/25
# 96/96 [==============================] - 3s 28ms/step - loss: 0.0066 - accuracy: 0.9942 - val_loss: 0.1628 - val_accuracy: 0.7597
# Epoch 18/25
# 96/96 [==============================] - 3s 28ms/step - loss: 0.0079 - accuracy: 0.9927 - val_loss: 0.1558 - val_accuracy: 0.7733
# Epoch 19/25
# 96/96 [==============================] - 3s 28ms/step - loss: 0.0057 - accuracy: 0.9949 - val_loss: 0.1684 - val_accuracy: 0.7460
# Epoch 20/25
# 96/96 [==============================] - 3s 28ms/step - loss: 0.0074 - accuracy: 0.9931 - val_loss: 0.1608 - val_accuracy: 0.7597
# Epoch 21/25
# 96/96 [==============================] - 3s 29ms/step - loss: 0.0089 - accuracy: 0.9915 - val_loss: 0.1644 - val_accuracy: 0.7572
# Epoch 22/25
#  - ETA: 2s - loss: 0.0046 - accuracy: 0.9958
# Epoch 23/25
# 96/96 [==============================] - 3s 28ms/step - loss: 0.0067 - accuracy: 0.9936 - val_loss: 0.1623 - val_accuracy: 0.7597
# Epoch 24/25
# 96/96 [==============================] - 3s 29ms/step - loss: 0.0063 - accuracy: 0.9939 - val_loss: 0.1626 - val_accuracy: 0.7597
# Epoch 25/25
# 96/96 [==============================] - 3s 28ms/step - loss: 0.0065 - accuracy: 0.9938 - val_loss: 0.1674 - val_accuracy: 0.7460
# test_TP: 99
# test_TN: 0
# test_FP: 0
# test_FN: 77
# * Accuracy on training set: 99.34%
# * Accuracy on validation set: 78.16%
# * Accuracy on test set: 56.25%
# ==========================================
#
#
# Epoch 1/25
# 96/96 [==============================] - 6s 38ms/step - loss: 0.0072 - accuracy: 0.9930 - val_loss: 0.1750 - val_accuracy: 0.7460
# Epoch 2/25
#  - ETA: 3s - loss: 0.0048 - accuracy: 0.9954
# Epoch 3/25
# 96/96 [==============================] - 3s 29ms/step - loss: 0.0066 - accuracy: 0.9935 - val_loss: 0.1359 - val_accuracy: 0.8250
# Epoch 4/25
# 96/96 [==============================] - 3s 29ms/step - loss: 0.0070 - accuracy: 0.9932 - val_loss: 0.1609 - val_accuracy: 0.7733
# Epoch 5/25
# 96/96 [==============================] - 3s 29ms/step - loss: 0.0075 - accuracy: 0.9926 - val_loss: 0.1547 - val_accuracy: 0.7905
# Epoch 6/25
# 96/96 [==============================] - 3s 28ms/step - loss: 0.0066 - accuracy: 0.9934 - val_loss: 0.1660 - val_accuracy: 0.7597
# Epoch 7/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0059 - accuracy: 0.9941 - val_loss: 0.1725 - val_accuracy: 0.7460
# Epoch 8/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0058 - accuracy: 0.9942 - val_loss: 0.1684 - val_accuracy: 0.7597
# Epoch 9/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0068 - accuracy: 0.9933 - val_loss: 0.1669 - val_accuracy: 0.7597
# Epoch 10/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0068 - accuracy: 0.9932 - val_loss: 0.1435 - val_accuracy: 0.8250
# Epoch 11/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0069 - accuracy: 0.9931 - val_loss: 0.1644 - val_accuracy: 0.7733
# Epoch 12/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0060 - accuracy: 0.9940 - val_loss: 0.1712 - val_accuracy: 0.7597
# Epoch 13/25
# 96/96 [==============================] - 3s 28ms/step - loss: 0.0067 - accuracy: 0.9933 - val_loss: 0.1555 - val_accuracy: 0.8078
# Epoch 14/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0068 - accuracy: 0.9932 - val_loss: 0.1541 - val_accuracy: 0.8078
# Epoch 15/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0071 - accuracy: 0.9929 - val_loss: 0.1615 - val_accuracy: 0.7733
# Epoch 16/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0065 - accuracy: 0.9935 - val_loss: 0.1612 - val_accuracy: 0.7733
# Epoch 17/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0072 - accuracy: 0.9928 - val_loss: 0.1586 - val_accuracy: 0.7733
# Epoch 18/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0070 - accuracy: 0.9930 - val_loss: 0.1592 - val_accuracy: 0.7733
# Epoch 19/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0067 - accuracy: 0.9933 - val_loss: 0.1632 - val_accuracy: 0.7733
# Epoch 20/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0064 - accuracy: 0.9936 - val_loss: 0.1566 - val_accuracy: 0.8078
# Epoch 21/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0070 - accuracy: 0.9930 - val_loss: 0.1673 - val_accuracy: 0.7597
# Epoch 22/25
#  - ETA: 0s - loss: 0.0075 - accuracy: 0.9925
# Epoch 23/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0061 - accuracy: 0.9939 - val_loss: 0.1601 - val_accuracy: 0.7733
# Epoch 24/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0066 - accuracy: 0.9933 - val_loss: 0.1670 - val_accuracy: 0.7597
# Epoch 25/25
# 96/96 [==============================] - 3s 27ms/step - loss: 0.0059 - accuracy: 0.9941 - val_loss: 0.1809 - val_accuracy: 0.7560
# test_TP: 97
# test_TN: 0
# test_FP: 0
# test_FN: 79
# * Accuracy on training set: 99.34%
# * Accuracy on validation set: 79.43%
# * Accuracy on test set: 55.11%
# ==========================================
#
#
# Epoch 1/25
#  - ETA: 1s - loss: 0.0067 - accuracy: 0.9933
# Epoch 2/25
# 96/96 [==============================] - 2s 24ms/step - loss: 0.0069 - accuracy: 0.9931 - val_loss: 0.1591 - val_accuracy: 0.7776
# Epoch 3/25
# 96/96 [==============================] - 2s 24ms/step - loss: 0.0064 - accuracy: 0.9935 - val_loss: 0.1580 - val_accuracy: 0.7905
# Epoch 4/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.0058 - accuracy: 0.9942 - val_loss: 0.1695 - val_accuracy: 0.7597
# Epoch 5/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.0072 - accuracy: 0.9928 - val_loss: 0.1787 - val_accuracy: 0.7560
# Epoch 6/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.0060 - accuracy: 0.9940 - val_loss: 0.1535 - val_accuracy: 0.8078
# Epoch 7/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.0064 - accuracy: 0.9936 - val_loss: 0.1301 - val_accuracy: 0.8522
# Epoch 8/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.0083 - accuracy: 0.9917 - val_loss: 0.1655 - val_accuracy: 0.7733
# Epoch 9/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.0062 - accuracy: 0.9938 - val_loss: 0.1728 - val_accuracy: 0.7460
# Epoch 10/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.0066 - accuracy: 0.9934 - val_loss: 0.1643 - val_accuracy: 0.7733
# Epoch 11/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.0060 - accuracy: 0.9940 - val_loss: 0.1582 - val_accuracy: 0.7991
# Epoch 12/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.0073 - accuracy: 0.9927 - val_loss: 0.1631 - val_accuracy: 0.7733
# Epoch 13/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.0061 - accuracy: 0.9938 - val_loss: 0.1628 - val_accuracy: 0.7733
# Epoch 14/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.0069 - accuracy: 0.9931 - val_loss: 0.1458 - val_accuracy: 0.8078
# Epoch 15/25
#  - ETA: 1s - loss: 0.0050 - accuracy: 0.9950
# Epoch 16/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.0068 - accuracy: 0.9931 - val_loss: 0.1575 - val_accuracy: 0.7905
# Epoch 17/25
# 96/96 [==============================] - 2s 26ms/step - loss: 0.0060 - accuracy: 0.9940 - val_loss: 0.1557 - val_accuracy: 0.7905
# Epoch 18/25
# 96/96 [==============================] - 2s 25ms/step - loss: 0.0067 - accuracy: 0.9933 - val_loss: 0.1450 - val_accuracy: 0.8078
# Epoch 19/25
# 96/96 [==============================] - 2s 26ms/step - loss: 0.0067 - accuracy: 0.9932 - val_loss: 0.1294 - val_accuracy: 0.8357
# Epoch 20/25
# 96/96 [==============================] - 2s 25ms/step - loss: 3.5949e-04 - accuracy: 1.0000 - val_loss: 0.1683 - val_accuracy: 0.7905
# Epoch 21/25
# 96/96 [==============================] - 2s 26ms/step - loss: 4.1306e-05 - accuracy: 1.0000 - val_loss: 0.1656 - val_accuracy: 0.7948
# Epoch 22/25
# 96/96 [==============================] - 2s 26ms/step - loss: 2.4837e-05 - accuracy: 1.0000 - val_loss: 0.1607 - val_accuracy: 0.7948
# Epoch 23/25
# 96/96 [==============================] - 2s 26ms/step - loss: 1.8622e-05 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.8221
# Epoch 24/25
# 96/96 [==============================] - 2s 25ms/step - loss: 1.4987e-05 - accuracy: 1.0000 - val_loss: 0.1580 - val_accuracy: 0.7912
# Epoch 25/25
# 96/96 [==============================] - 2s 25ms/step - loss: 1.1322e-05 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.8023
# test_TP: 98
# test_TN: 0
# test_FP: 0
# test_FN: 78
# * Accuracy on training set: 100.00%
# * Accuracy on validation set: 83.23%
# * Accuracy on test set: 55.68%
# ==========================================
#
#
# Epoch 1/25
# 96/96 [==============================] - 11s 94ms/step - loss: 1.3465e-05 - accuracy: 1.0000 - val_loss: 0.1627 - val_accuracy: 0.7912
# Epoch 2/25
# 96/96 [==============================] - 2s 25ms/step - loss: 6.1981e-06 - accuracy: 1.0000 - val_loss: 0.1543 - val_accuracy: 0.8048
# Epoch 3/25
# 96/96 [==============================] - 2s 25ms/step - loss: 3.6528e-06 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.7776
# Epoch 4/25
# 96/96 [==============================] - 2s 25ms/step - loss: 2.2220e-06 - accuracy: 1.0000 - val_loss: 0.1536 - val_accuracy: 0.8048
# Epoch 5/25
# 96/96 [==============================] - 2s 25ms/step - loss: 1.7608e-06 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.8048
# Epoch 6/25
# 96/96 [==============================] - 3s 26ms/step - loss: 1.4507e-06 - accuracy: 1.0000 - val_loss: 0.1558 - val_accuracy: 0.8048
# Epoch 7/25
# 96/96 [==============================] - 3s 26ms/step - loss: 1.2361e-06 - accuracy: 1.0000 - val_loss: 0.1730 - val_accuracy: 0.7776
# Epoch 8/25
# 96/96 [==============================] - 3s 26ms/step - loss: 1.5581e-06 - accuracy: 1.0000 - val_loss: 0.1575 - val_accuracy: 0.8048
# Epoch 9/25
# 96/96 [==============================] - 2s 26ms/step - loss: 7.8933e-07 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.8048
# Epoch 10/25
# 96/96 [==============================] - 3s 26ms/step - loss: 7.7721e-07 - accuracy: 1.0000 - val_loss: 0.1600 - val_accuracy: 0.7912
# Epoch 11/25
# 96/96 [==============================] - 3s 26ms/step - loss: 6.9230e-07 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.8048
# Epoch 12/25
# 96/96 [==============================] - 3s 26ms/step - loss: 9.1919e-06 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.8084
# Epoch 13/25
# 96/96 [==============================] - 3s 26ms/step - loss: 1.0384e-06 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.8048
# Epoch 14/25
# 96/96 [==============================] - 3s 26ms/step - loss: 9.5138e-07 - accuracy: 1.0000 - val_loss: 0.1609 - val_accuracy: 0.7912
# Epoch 15/25
# 96/96 [==============================] - 2s 26ms/step - loss: 8.1570e-07 - accuracy: 1.0000 - val_loss: 0.1610 - val_accuracy: 0.7912
# Epoch 16/25
# 96/96 [==============================] - 3s 26ms/step - loss: 7.3702e-07 - accuracy: 1.0000 - val_loss: 0.1540 - val_accuracy: 0.8048
# Epoch 17/25
# 96/96 [==============================] - 3s 26ms/step - loss: 6.9075e-07 - accuracy: 1.0000 - val_loss: 0.1585 - val_accuracy: 0.8048
# Epoch 18/25
# 96/96 [==============================] - 2s 26ms/step - loss: 8.8626e-07 - accuracy: 1.0000 - val_loss: 0.1594 - val_accuracy: 0.8048
# Epoch 19/25
# 96/96 [==============================] - 3s 27ms/step - loss: 9.4663e-07 - accuracy: 1.0000 - val_loss: 0.1558 - val_accuracy: 0.8048
# Epoch 20/25
# 96/96 [==============================] - 3s 26ms/step - loss: 6.7336e-07 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.8048
# Epoch 21/25
# 96/96 [==============================] - 3s 26ms/step - loss: 4.8407e-07 - accuracy: 1.0000 - val_loss: 0.1554 - val_accuracy: 0.8048
# Epoch 22/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.3789e-07 - accuracy: 1.0000 - val_loss: 0.1572 - val_accuracy: 0.8048
# Epoch 23/25
# 96/96 [==============================] - 3s 27ms/step - loss: 4.5195e-07 - accuracy: 1.0000 - val_loss: 0.1658 - val_accuracy: 0.7776
# Epoch 24/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.5481e-07 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.8048
# Epoch 25/25
# 96/96 [==============================] - 2s 26ms/step - loss: 4.2571e-07 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.8048
# test_TP: 92
# test_TN: 0
# test_FP: 0
# test_FN: 84
# * Accuracy on training set: 100.00%
# * Accuracy on validation set: 83.54%
# * Accuracy on test set: 52.27%
# ==========================================
#
#
# Epoch 1/25
# 96/96 [==============================] - 15s 136ms/step - loss: 8.3523e-07 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.8048
# Epoch 2/25
# 96/96 [==============================] - 3s 26ms/step - loss: 6.6981e-07 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.8048
# Epoch 3/25
# 96/96 [==============================] - 3s 26ms/step - loss: 4.0403e-07 - accuracy: 1.0000 - val_loss: 0.1622 - val_accuracy: 0.7912
# Epoch 4/25
# 96/96 [==============================] - 3s 27ms/step - loss: 3.2364e-06 - accuracy: 1.0000 - val_loss: 0.1644 - val_accuracy: 0.7912
# Epoch 5/25
# 96/96 [==============================] - 3s 26ms/step - loss: 4.7671e-07 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 0.7948
# Epoch 6/25
# 96/96 [==============================] - 3s 26ms/step - loss: 3.4234e-07 - accuracy: 1.0000 - val_loss: 0.1536 - val_accuracy: 0.8048
# Epoch 7/25
# 96/96 [==============================] - 3s 27ms/step - loss: 4.0018e-07 - accuracy: 1.0000 - val_loss: 0.1581 - val_accuracy: 0.8048
# Epoch 8/25
# 96/96 [==============================] - 3s 27ms/step - loss: 2.5058e-07 - accuracy: 1.0000 - val_loss: 0.1612 - val_accuracy: 0.8048
# Epoch 9/25
# 96/96 [==============================] - 3s 27ms/step - loss: 4.6216e-07 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.8048
# Epoch 10/25
# 96/96 [==============================] - 3s 27ms/step - loss: 4.7686e-07 - accuracy: 1.0000 - val_loss: 0.1588 - val_accuracy: 0.8048
# Epoch 11/25
# 96/96 [==============================] - 3s 27ms/step - loss: 2.3703e-07 - accuracy: 1.0000 - val_loss: 0.1589 - val_accuracy: 0.8048
# Epoch 12/25
# 96/96 [==============================] - 3s 27ms/step - loss: 2.3106e-07 - accuracy: 1.0000 - val_loss: 0.1575 - val_accuracy: 0.8048
# Epoch 13/25
# 96/96 [==============================] - 3s 27ms/step - loss: 4.1677e-07 - accuracy: 1.0000 - val_loss: 0.1593 - val_accuracy: 0.8048
# Epoch 14/25
# 96/96 [==============================] - 3s 27ms/step - loss: 2.5781e-07 - accuracy: 1.0000 - val_loss: 0.1579 - val_accuracy: 0.8048
# Epoch 15/25
# 96/96 [==============================] - 3s 28ms/step - loss: 2.7730e-07 - accuracy: 1.0000 - val_loss: 0.1615 - val_accuracy: 0.7912
# Epoch 16/25
# 96/96 [==============================] - 3s 27ms/step - loss: 2.3998e-07 - accuracy: 1.0000 - val_loss: 0.1621 - val_accuracy: 0.7912
# Epoch 17/25
# 96/96 [==============================] - 3s 27ms/step - loss: 1.6433e-07 - accuracy: 1.0000 - val_loss: 0.1589 - val_accuracy: 0.8048
# Epoch 18/25
# 96/96 [==============================] - 3s 28ms/step - loss: 2.5514e-07 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.8048
# Epoch 19/25
# 96/96 [==============================] - 3s 28ms/step - loss: 1.6693e-07 - accuracy: 1.0000 - val_loss: 0.1765 - val_accuracy: 0.7640
# Epoch 20/25
# 96/96 [==============================] - 3s 28ms/step - loss: 2.4119e-07 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.8048
# Epoch 21/25
# 96/96 [==============================] - 3s 28ms/step - loss: 1.4660e-07 - accuracy: 1.0000 - val_loss: 0.1595 - val_accuracy: 0.8048
# Epoch 22/25
# 96/96 [==============================] - 3s 28ms/step - loss: 1.6746e-07 - accuracy: 1.0000 - val_loss: 0.1670 - val_accuracy: 0.7912
# Epoch 23/25
# 96/96 [==============================] - 3s 28ms/step - loss: 1.5363e-07 - accuracy: 1.0000 - val_loss: 0.1582 - val_accuracy: 0.8048
# Epoch 24/25
# 96/96 [==============================] - 3s 28ms/step - loss: 1.7096e-07 - accuracy: 1.0000 - val_loss: 0.1553 - val_accuracy: 0.8048
# Epoch 25/25
# 96/96 [==============================] - 3s 28ms/step - loss: 1.6410e-07 - accuracy: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.8048
# test_TP: 89
# test_TN: 0
# test_FP: 0
# test_FN: 87
# * Accuracy on training set: 100.00%
# * Accuracy on validation set: 83.54%
# * Accuracy on test set: 50.57%
# ==========================================
#
#
# Epoch 1/25
# 96/96 [==============================] - 4s 32ms/step - loss: 1.3757e-07 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.8048
# Epoch 2/25
# 96/96 [==============================] - 3s 28ms/step - loss: 1.2831e-07 - accuracy: 1.0000 - val_loss: 0.1596 - val_accuracy: 0.8048
# Epoch 3/25
# 96/96 [==============================] - 3s 28ms/step - loss: 7.3589e-07 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.8048
# Epoch 4/25
# 96/96 [==============================] - 3s 28ms/step - loss: 2.1391e-07 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.8048
# Epoch 5/25
# 96/96 [==============================] - 3s 28ms/step - loss: 1.3608e-07 - accuracy: 1.0000 - val_loss: 0.1542 - val_accuracy: 0.8048
# Epoch 6/25
# 96/96 [==============================] - 3s 28ms/step - loss: 1.2908e-07 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.7912
# Epoch 7/25
# 96/96 [==============================] - 3s 28ms/step - loss: 1.6961e-07 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 0.8048
# Epoch 8/25
# 96/96 [==============================] - 3s 28ms/step - loss: 1.0873e-07 - accuracy: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.8048
# Epoch 9/25
# 96/96 [==============================] - 3s 28ms/step - loss: 1.0226e-07 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.8048
# Epoch 10/25
# 96/96 [==============================] - 3s 27ms/step - loss: 1.0236e-07 - accuracy: 1.0000 - val_loss: 0.1637 - val_accuracy: 0.7912
# Epoch 11/25
# 96/96 [==============================] - 3s 28ms/step - loss: 8.9781e-08 - accuracy: 1.0000 - val_loss: 0.1549 - val_accuracy: 0.8048
# Epoch 12/25
# 96/96 [==============================] - 3s 28ms/step - loss: 8.8345e-08 - accuracy: 1.0000 - val_loss: 0.1585 - val_accuracy: 0.8048
# Epoch 13/25
# 96/96 [==============================] - 3s 28ms/step - loss: 9.7076e-08 - accuracy: 1.0000 - val_loss: 0.1576 - val_accuracy: 0.8048
# Epoch 14/25
# 96/96 [==============================] - 3s 28ms/step - loss: 1.0015e-07 - accuracy: 1.0000 - val_loss: 0.1634 - val_accuracy: 0.7912
# Epoch 15/25
#  - ETA: 1s - loss: 1.1359e-07 - accuracy: 1.0000
# Epoch 16/25
# 96/96 [==============================] - 3s 28ms/step - loss: 9.5036e-08 - accuracy: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.8048
# Epoch 17/25
# 96/96 [==============================] - 3s 28ms/step - loss: 9.8740e-08 - accuracy: 1.0000 - val_loss: 0.1590 - val_accuracy: 0.8048
# Epoch 18/25
# 96/96 [==============================] - 3s 27ms/step - loss: 8.0549e-08 - accuracy: 1.0000 - val_loss: 0.1588 - val_accuracy: 0.8048
# Epoch 19/25
# 96/96 [==============================] - 3s 27ms/step - loss: 9.0844e-08 - accuracy: 1.0000 - val_loss: 0.1579 - val_accuracy: 0.8048
# Epoch 20/25
# 96/96 [==============================] - 3s 27ms/step - loss: 9.5668e-08 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.8048
# Epoch 21/25
# 96/96 [==============================] - 3s 27ms/step - loss: 1.0894e-07 - accuracy: 1.0000 - val_loss: 0.1620 - val_accuracy: 0.7912
# Epoch 22/25
# 96/96 [==============================] - 3s 28ms/step - loss: 1.5254e-07 - accuracy: 1.0000 - val_loss: 0.1086 - val_accuracy: 0.8774
# Epoch 23/25
# 96/96 [==============================] - 3s 28ms/step - loss: 6.8861e-05 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.8121
# Epoch 24/25
# 96/96 [==============================] - 3s 27ms/step - loss: 1.5107e-07 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.7948
# Epoch 25/25
# 96/96 [==============================] - 3s 27ms/step - loss: 1.1015e-07 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.7948
# test_TP: 91
# test_TN: 0
# test_FP: 0
# test_FN: 85
# * Accuracy on training set: 100.00%
# * Accuracy on validation set: 82.28%
# * Accuracy on test set: 51.70%
# ==========================================
#
#
# Epoch 1/25
# 96/96 [==============================] - 5s 40ms/step - loss: 9.6595e-08 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.8121
# Epoch 2/25
# 96/96 [==============================] - 3s 27ms/step - loss: 9.2120e-08 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.8048
# Epoch 3/25
#  - ETA: 2s - loss: 1.2731e-07 - accuracy: 1.0000
# Epoch 4/25
# 96/96 [==============================] - 3s 28ms/step - loss: 7.8271e-08 - accuracy: 1.0000 - val_loss: 0.1820 - val_accuracy: 0.7331
# Epoch 5/25
# 96/96 [==============================] - 3s 28ms/step - loss: 8.0588e-08 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.8048
# Epoch 6/25
# 96/96 [==============================] - 3s 27ms/step - loss: 2.4426e-07 - accuracy: 1.0000 - val_loss: 0.1431 - val_accuracy: 0.8121
# Epoch 7/25
# 96/96 [==============================] - 3s 27ms/step - loss: 1.9703e-05 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.8121
# Epoch 8/25
# 96/96 [==============================] - 3s 27ms/step - loss: 2.0044e-07 - accuracy: 1.0000 - val_loss: 0.1614 - val_accuracy: 0.8221
# Epoch 9/25
# 96/96 [==============================] - 2s 26ms/step - loss: 2.1876e-07 - accuracy: 1.0000 - val_loss: 0.1580 - val_accuracy: 0.8221
# Epoch 10/25
#  - ETA: 0s - loss: 2.3443e-07 - accuracy: 1.0000
# Epoch 11/25
# 96/96 [==============================] - 2s 26ms/step - loss: 1.2279e-07 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.8221
# Epoch 12/25
# 96/96 [==============================] - 2s 26ms/step - loss: 1.6819e-07 - accuracy: 1.0000 - val_loss: 0.1543 - val_accuracy: 0.8221
# Epoch 13/25
# 96/96 [==============================] - 3s 26ms/step - loss: 1.3154e-07 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.8221
# Epoch 14/25
# 96/96 [==============================] - 3s 27ms/step - loss: 1.9264e-07 - accuracy: 1.0000 - val_loss: 0.1558 - val_accuracy: 0.8221
# Epoch 15/25
# 96/96 [==============================] - 3s 27ms/step - loss: 1.6812e-07 - accuracy: 1.0000 - val_loss: 0.1614 - val_accuracy: 0.8221
# Epoch 16/25
# 96/96 [==============================] - 3s 27ms/step - loss: 1.1103e-07 - accuracy: 1.0000 - val_loss: 0.1585 - val_accuracy: 0.8221
# Epoch 17/25
# 96/96 [==============================] - 3s 27ms/step - loss: 1.3377e-07 - accuracy: 1.0000 - val_loss: 0.1592 - val_accuracy: 0.8221
# Epoch 18/25
#  - ETA: 0s - loss: 1.2116e-07 - accuracy: 1.0000
# Epoch 19/25
# 96/96 [==============================] - 3s 27ms/step - loss: 1.0466e-07 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.8221
# Epoch 20/25
# 96/96 [==============================] - 3s 27ms/step - loss: 1.1405e-07 - accuracy: 1.0000 - val_loss: 0.1554 - val_accuracy: 0.8221
# Epoch 21/25
#  - 3s 27ms/step - loss: 1.0728e-07 - accuracy: 1.0000 - val_loss: 0.1554 - val_accuracy: 0.8221
# Epoch 22/25
# 96/96 [==============================] - 3s 27ms/step - loss: 1.2126e-07 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 0.8221
# Epoch 23/25
# 96/96 [==============================] - 3s 27ms/step - loss: 1.0296e-07 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.8221
# Epoch 24/25
# 96/96 [==============================] - 3s 27ms/step - loss: 9.8595e-08 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.8221
# Epoch 25/25
# 96/96 [==============================] - 3s 27ms/step - loss: 1.0929e-07 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.8221
# test_TP: 92
# test_TN: 0
# test_FP: 0
# test_FN: 84
# * Accuracy on training set: 100.00%
# * Accuracy on validation set: 84.81%
# * Accuracy on test set: 52.27%
# ==========================================
#
#
# Epoch 1/25
# 96/96 [==============================] - 9s 37ms/step - loss: 1.0750e-07 - accuracy: 1.0000 - val_loss: 0.1595 - val_accuracy: 0.8221
# Epoch 2/25
# 96/96 [==============================] - 3s 27ms/step - loss: 1.3801e-07 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.8221
# Epoch 3/25
# 96/96 [==============================] - 3s 27ms/step - loss: 8.9470e-08 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.8221
# Epoch 4/25
# 96/96 [==============================] - 3s 27ms/step - loss: 8.0133e-08 - accuracy: 1.0000 - val_loss: 0.1566 - val_accuracy: 0.8048
# Epoch 5/25
# 96/96 [==============================] - 3s 26ms/step - loss: 8.1915e-08 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.8257
# Epoch 6/25
# 96/96 [==============================] - 3s 26ms/step - loss: 9.3863e-08 - accuracy: 1.0000 - val_loss: 0.1540 - val_accuracy: 0.8048
# Epoch 7/25
# 96/96 [==============================] - 3s 26ms/step - loss: 6.7207e-08 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.8048
# Epoch 8/25
# 96/96 [==============================] - 3s 26ms/step - loss: 6.9101e-08 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 0.8048
# Epoch 9/25
# 96/96 [==============================] - 3s 27ms/step - loss: 7.8024e-08 - accuracy: 1.0000 - val_loss: 0.1660 - val_accuracy: 0.7912
# Epoch 10/25
# 96/96 [==============================] - 3s 26ms/step - loss: 1.2844e-07 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.8048
# Epoch 11/25
#  - ETA: 1s - loss: 6.2514e-08 - accuracy: 1.0000
# Epoch 12/25
# 96/96 [==============================] - 3s 27ms/step - loss: 6.2740e-08 - accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.8048
# Epoch 13/25
# 96/96 [==============================] - 3s 30ms/step - loss: 6.6264e-08 - accuracy: 1.0000 - val_loss: 0.1743 - val_accuracy: 0.7776
# Epoch 14/25
# 96/96 [==============================] - 3s 31ms/step - loss: 6.4509e-08 - accuracy: 1.0000 - val_loss: 0.1572 - val_accuracy: 0.8048
# Epoch 15/25
#  - ETA: 1s - loss: 5.8763e-08 - accuracy: 1.0000
# Epoch 16/25
# 96/96 [==============================] - 3s 29ms/step - loss: 5.9624e-08 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.8121
# Epoch 17/25
#  - ETA: 1s - loss: 5.6614e-08 - accuracy: 1.0000
# Epoch 18/25
# 96/96 [==============================] - 3s 30ms/step - loss: 5.7771e-08 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 0.8048
# Epoch 19/25
# 96/96 [==============================] - 3s 29ms/step - loss: 6.1611e-08 - accuracy: 1.0000 - val_loss: 0.1540 - val_accuracy: 0.8048
# Epoch 20/25
# 96/96 [==============================] - 3s 28ms/step - loss: 1.6293e-07 - accuracy: 1.0000 - val_loss: 0.1558 - val_accuracy: 0.8048
# Epoch 21/25
# 96/96 [==============================] - 3s 28ms/step - loss: 6.1906e-08 - accuracy: 1.0000 - val_loss: 0.1558 - val_accuracy: 0.8048
# Epoch 22/25
# 96/96 [==============================] - 3s 28ms/step - loss: 6.0157e-08 - accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.8048
# Epoch 23/25
# 96/96 [==============================] - 3s 28ms/step - loss: 6.8762e-08 - accuracy: 1.0000 - val_loss: 0.1546 - val_accuracy: 0.8048
# Epoch 24/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.8935e-08 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.8048
# Epoch 25/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.5427e-08 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.8048
# test_TP: 88
# test_TN: 0
# test_FP: 0
# test_FN: 88
# * Accuracy on training set: 100.00%
# * Accuracy on validation set: 83.54%
# * Accuracy on test set: 50.00%
# ==========================================
#
#
# Epoch 1/25
# 96/96 [==============================] - 10s 80ms/step - loss: 5.7679e-08 - accuracy: 1.0000 - val_loss: 0.1543 - val_accuracy: 0.8048
# Epoch 2/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.5690e-08 - accuracy: 1.0000 - val_loss: 0.1608 - val_accuracy: 0.8048
# Epoch 3/25
# 96/96 [==============================] - 3s 29ms/step - loss: 5.6690e-08 - accuracy: 1.0000 - val_loss: 0.1588 - val_accuracy: 0.8048
# Epoch 4/25
# 96/96 [==============================] - 3s 29ms/step - loss: 5.6892e-08 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.8048
# Epoch 5/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.7309e-08 - accuracy: 1.0000 - val_loss: 0.1558 - val_accuracy: 0.8048
# Epoch 6/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.5375e-08 - accuracy: 1.0000 - val_loss: 0.1597 - val_accuracy: 0.8048
# Epoch 7/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.3464e-08 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.7948
# Epoch 8/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.5769e-08 - accuracy: 1.0000 - val_loss: 0.1543 - val_accuracy: 0.8048
# Epoch 9/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.3017e-08 - accuracy: 1.0000 - val_loss: 0.1647 - val_accuracy: 0.7912
# Epoch 10/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.3601e-08 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.8048
# Epoch 11/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.4071e-08 - accuracy: 1.0000 - val_loss: 0.1589 - val_accuracy: 0.8048
# Epoch 12/25
#  - ETA: 0s - loss: 5.4687e-08 - accuracy: 1.0000
# Epoch 13/25
# 96/96 [==============================] - 3s 28ms/step - loss: 1.4241e-07 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.8048
# Epoch 14/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.7849e-08 - accuracy: 1.0000 - val_loss: 0.1543 - val_accuracy: 0.8048
# Epoch 15/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.6420e-08 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.8048
# Epoch 16/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.6823e-08 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.8048
# Epoch 17/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.4151e-08 - accuracy: 1.0000 - val_loss: 0.1546 - val_accuracy: 0.8048
# Epoch 18/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.5249e-08 - accuracy: 1.0000 - val_loss: 0.1600 - val_accuracy: 0.8048
# Epoch 19/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.4914e-08 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.8048
# Epoch 20/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.6546e-08 - accuracy: 1.0000 - val_loss: 0.1536 - val_accuracy: 0.8048
# Epoch 21/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.4268e-08 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.8048
# Epoch 22/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.4087e-08 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 0.8048
# Epoch 23/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.4488e-08 - accuracy: 1.0000 - val_loss: 0.1535 - val_accuracy: 0.8048
# Epoch 24/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.4059e-08 - accuracy: 1.0000 - val_loss: 0.1562 - val_accuracy: 0.8048
# Epoch 25/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.5967e-08 - accuracy: 1.0000 - val_loss: 0.1600 - val_accuracy: 0.8048
# test_TP: 88
# test_TN: 0
# test_FP: 0
# test_FN: 88
# * Accuracy on training set: 100.00%
# * Accuracy on validation set: 83.54%
# * Accuracy on test set: 50.00%
# ==========================================
#
#
# Epoch 1/25
# 96/96 [==============================] - 8s 37ms/step - loss: 5.7063e-08 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.7948
# Epoch 2/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.4575e-08 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.8048
# Epoch 3/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.3492e-08 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 0.8048
# Epoch 4/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.2382e-08 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.8048
# Epoch 5/25
# 96/96 [==============================] - 2s 26ms/step - loss: 6.2409e-08 - accuracy: 1.0000 - val_loss: 0.1533 - val_accuracy: 0.8048
# Epoch 6/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.2741e-08 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.8048
# Epoch 7/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.4010e-08 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 0.8048
# Epoch 8/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.3212e-08 - accuracy: 1.0000 - val_loss: 0.1542 - val_accuracy: 0.8048
# Epoch 9/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.3062e-08 - accuracy: 1.0000 - val_loss: 0.1621 - val_accuracy: 0.8048
# Epoch 10/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.3779e-08 - accuracy: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.8048
# Epoch 11/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.2002e-08 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.8048
# Epoch 12/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.1849e-08 - accuracy: 1.0000 - val_loss: 0.1575 - val_accuracy: 0.8048
# Epoch 13/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.5146e-08 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.8048
# Epoch 14/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.1862e-08 - accuracy: 1.0000 - val_loss: 0.1566 - val_accuracy: 0.8048
# Epoch 15/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.1344e-08 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.8048
# Epoch 16/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.1855e-08 - accuracy: 1.0000 - val_loss: 0.1602 - val_accuracy: 0.8048
# Epoch 17/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.3175e-08 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.8048
# Epoch 18/25
#  - ETA: 2s - loss: 5.4685e-08 - accuracy: 1.0000
# Epoch 19/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.4400e-08 - accuracy: 1.0000 - val_loss: 0.1586 - val_accuracy: 0.8048
# Epoch 20/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.6861e-08 - accuracy: 1.0000 - val_loss: 0.1586 - val_accuracy: 0.8048
# Epoch 21/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.4389e-08 - accuracy: 1.0000 - val_loss: 0.1586 - val_accuracy: 0.8048
# Epoch 22/25
# 96/96 [==============================] - 2s 26ms/step - loss: 7.6285e-08 - accuracy: 1.0000 - val_loss: 0.1586 - val_accuracy: 0.8048
# Epoch 23/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.9564e-08 - accuracy: 1.0000 - val_loss: 0.1586 - val_accuracy: 0.8048
# Epoch 24/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.5542e-08 - accuracy: 1.0000 - val_loss: 0.1586 - val_accuracy: 0.8048
# Epoch 25/25
# 96/96 [==============================] - 2s 25ms/step - loss: 5.6468e-08 - accuracy: 1.0000 - val_loss: 0.1586 - val_accuracy: 0.8048
# test_TP: 88
# test_TN: 0
# test_FP: 0
# test_FN: 88
# * Accuracy on training set: 100.00%
# * Accuracy on validation set: 83.54%
# * Accuracy on test set: 50.00%
# ==========================================
#
#
# Epoch 1/25
# 96/96 [==============================] - 15s 105ms/step - loss: 5.6387e-08 - accuracy: 1.0000 - val_loss: 0.1583 - val_accuracy: 0.8048
# Epoch 2/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.5642e-08 - accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 0.8048
# Epoch 3/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.6186e-08 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 0.8048
# Epoch 4/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.2671e-08 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.7948
# Epoch 5/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.4758e-08 - accuracy: 1.0000 - val_loss: 0.1625 - val_accuracy: 0.8048
# Epoch 6/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.3173e-08 - accuracy: 1.0000 - val_loss: 0.1667 - val_accuracy: 0.7912
# Epoch 7/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.3396e-08 - accuracy: 1.0000 - val_loss: 0.1594 - val_accuracy: 0.8048
# Epoch 8/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.4768e-08 - accuracy: 1.0000 - val_loss: 0.1627 - val_accuracy: 0.8048
# Epoch 9/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.2218e-08 - accuracy: 1.0000 - val_loss: 0.1599 - val_accuracy: 0.8048
# Epoch 10/25
#  - ETA: 0s - loss: 5.2341e-08 - accuracy: 1.0000
# Epoch 11/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.1805e-08 - accuracy: 1.0000 - val_loss: 0.1590 - val_accuracy: 0.8048
# Epoch 12/25
# 96/96 [==============================] - 2s 25ms/step - loss: 5.1549e-08 - accuracy: 1.0000 - val_loss: 0.1583 - val_accuracy: 0.8048
# Epoch 13/25
#  - ETA: 1s - loss: 5.1299e-08 - accuracy: 1.0000
# Epoch 14/25
# 96/96 [==============================] - 3s 30ms/step - loss: 5.2379e-08 - accuracy: 1.0000 - val_loss: 0.1583 - val_accuracy: 0.8048
# Epoch 15/25
# 96/96 [==============================] - 3s 30ms/step - loss: 5.2399e-08 - accuracy: 1.0000 - val_loss: 0.1594 - val_accuracy: 0.8048
# Epoch 16/25
# 96/96 [==============================] - 3s 30ms/step - loss: 5.1768e-08 - accuracy: 1.0000 - val_loss: 0.1592 - val_accuracy: 0.8048
# Epoch 17/25
# 96/96 [==============================] - 3s 30ms/step - loss: 5.2614e-08 - accuracy: 1.0000 - val_loss: 0.1653 - val_accuracy: 0.7912
# Epoch 18/25
# 96/96 [==============================] - 3s 29ms/step - loss: 5.1461e-08 - accuracy: 1.0000 - val_loss: 0.1599 - val_accuracy: 0.8048
# Epoch 19/25
#  - ETA: 2s - loss: 5.1676e-08 - accuracy: 1.0000
# Epoch 20/25
# 96/96 [==============================] - 3s 30ms/step - loss: 5.2539e-08 - accuracy: 1.0000 - val_loss: 0.1597 - val_accuracy: 0.8048
# Epoch 21/25
# 96/96 [==============================] - 3s 30ms/step - loss: 5.1369e-08 - accuracy: 1.0000 - val_loss: 0.1617 - val_accuracy: 0.8048
# Epoch 22/25
# 96/96 [==============================] - 3s 30ms/step - loss: 5.0465e-08 - accuracy: 1.0000 - val_loss: 0.1585 - val_accuracy: 0.8048
# Epoch 23/25
#  - ETA: 1s - loss: 5.0523e-08 - accuracy: 1.0000
# Epoch 24/25
# 96/96 [==============================] - 3s 31ms/step - loss: 5.0933e-08 - accuracy: 1.0000 - val_loss: 0.1601 - val_accuracy: 0.8048
# Epoch 25/25
#  - ETA: 1s - loss: 9.3927e-08 - accuracy: 1.0000
# test_TP: 89
# test_TN: 0
# test_FP: 0
# test_FN: 87
# * Accuracy on training set: 100.00%
# * Accuracy on validation set: 82.28%
# * Accuracy on test set: 50.57%
# ==========================================
#
#
# Epoch 1/25
# 96/96 [==============================] - 6s 45ms/step - loss: 5.0355e-08 - accuracy: 1.0000 - val_loss: 0.1634 - val_accuracy: 0.7912
# Epoch 2/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.2242e-08 - accuracy: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.8048
# Epoch 3/25
# 96/96 [==============================] - 3s 32ms/step - loss: 5.0616e-08 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.8048
# Epoch 4/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.0610e-08 - accuracy: 1.0000 - val_loss: 0.1562 - val_accuracy: 0.8048
# Epoch 5/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.9388e-08 - accuracy: 1.0000 - val_loss: 0.1616 - val_accuracy: 0.8048
# Epoch 6/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0988e-08 - accuracy: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.8048
# Epoch 7/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0899e-08 - accuracy: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.8048
# Epoch 8/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.1170e-08 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 0.8048
# Epoch 9/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.1151e-08 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.8048
# Epoch 10/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.1245e-08 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.8048
# Epoch 11/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.1153e-08 - accuracy: 1.0000 - val_loss: 0.1592 - val_accuracy: 0.8048
# Epoch 12/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0466e-08 - accuracy: 1.0000 - val_loss: 0.1597 - val_accuracy: 0.8048
# Epoch 13/25
# 96/96 [==============================] - 3s 29ms/step - loss: 5.3190e-08 - accuracy: 1.0000 - val_loss: 0.1642 - val_accuracy: 0.7912
# Epoch 14/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.0880e-08 - accuracy: 1.0000 - val_loss: 0.1619 - val_accuracy: 0.8048
# Epoch 15/25
# 96/96 [==============================] - 3s 29ms/step - loss: 5.1412e-08 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.8048
# Epoch 16/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.0741e-08 - accuracy: 1.0000 - val_loss: 0.1607 - val_accuracy: 0.8048
# Epoch 17/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.1748e-08 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.8048
# Epoch 18/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0164e-08 - accuracy: 1.0000 - val_loss: 0.1575 - val_accuracy: 0.8048
# Epoch 19/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.2972e-08 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 0.8293
# Epoch 20/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.6786e-08 - accuracy: 1.0000 - val_loss: 0.1625 - val_accuracy: 0.8048
# Epoch 21/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0391e-08 - accuracy: 1.0000 - val_loss: 0.1608 - val_accuracy: 0.8048
# Epoch 22/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.2431e-08 - accuracy: 1.0000 - val_loss: 0.1861 - val_accuracy: 0.7331
# Epoch 23/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.2926e-08 - accuracy: 1.0000 - val_loss: 0.1716 - val_accuracy: 0.7912
# Epoch 24/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.1215e-08 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.7912
# Epoch 25/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0886e-08 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.7912
# test_TP: 88
# test_TN: 0
# test_FP: 0
# test_FN: 88
# * Accuracy on training set: 100.00%
# * Accuracy on validation set: 82.28%
# * Accuracy on test set: 50.00%
# ==========================================
#
#
# Epoch 1/25
#  - ETA: 2s - loss: 5.0729e-08 - accuracy: 1.0000
# Epoch 2/25
# 96/96 [==============================] - 3s 29ms/step - loss: 5.0902e-08 - accuracy: 1.0000 - val_loss: 0.1623 - val_accuracy: 0.8048
# Epoch 3/25
# ...
# Epoch 18/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0570e-08 - accuracy: 1.0000 - val_loss: 0.1592 - val_accuracy: 0.8048
# Epoch 19/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.1048e-08 - accuracy: 1.0000 - val_loss: 0.1596 - val_accuracy: 0.8048
# Epoch 20/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0456e-08 - accuracy: 1.0000 - val_loss: 0.1596 - val_accuracy: 0.8048
# Epoch 21/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0595e-08 - accuracy: 1.0000 - val_loss: 0.1596 - val_accuracy: 0.8048
# Epoch 22/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0660e-08 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 0.8048
# Epoch 23/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0938e-08 - accuracy: 1.0000 - val_loss: 0.1588 - val_accuracy: 0.8048
# Epoch 24/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0598e-08 - accuracy: 1.0000 - val_loss: 0.1795 - val_accuracy: 0.7503
# Epoch 25/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0518e-08 - accuracy: 1.0000 - val_loss: 0.1722 - val_accuracy: 0.7912
# test_TP: 88
# test_TN: 0
# test_FP: 0
# test_FN: 88
# * Accuracy on training set: 100.00%
# * Accuracy on validation set: 82.28%
# * Accuracy on test set: 50.00%
# ==========================================
#
#
# Epoch 1/25
# 96/96 [==============================] - 6s 44ms/step - loss: 5.0176e-08 - accuracy: 1.0000 - val_loss: 0.1717 - val_accuracy: 0.7912
# Epoch 2/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0717e-08 - accuracy: 1.0000 - val_loss: 0.1709 - val_accuracy: 0.7912
# Epoch 3/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0728e-08 - accuracy: 1.0000 - val_loss: 0.1690 - val_accuracy: 0.7912
# Epoch 4/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0503e-08 - accuracy: 1.0000 - val_loss: 0.1646 - val_accuracy: 0.7912
# Epoch 5/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0318e-08 - accuracy: 1.0000 - val_loss: 0.1625 - val_accuracy: 0.8048
# Epoch 6/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0693e-08 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.8048
# Epoch 7/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0451e-08 - accuracy: 1.0000 - val_loss: 0.1627 - val_accuracy: 0.8048
# Epoch 8/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0705e-08 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.8048
# Epoch 9/25
# 96/96 [==============================] - 3s 26ms/step - loss: 4.9989e-08 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 0.8048
# Epoch 10/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0523e-08 - accuracy: 1.0000 - val_loss: 0.1625 - val_accuracy: 0.8048
# Epoch 11/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.1430e-08 - accuracy: 1.0000 - val_loss: 0.1637 - val_accuracy: 0.7912
# Epoch 12/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0536e-08 - accuracy: 1.0000 - val_loss: 0.1632 - val_accuracy: 0.8048
# Epoch 13/25
# 96/96 [==============================] - 3s 30ms/step - loss: 5.0477e-08 - accuracy: 1.0000 - val_loss: 0.1612 - val_accuracy: 0.8048
# Epoch 14/25
#  - ETA: 1s - loss: 5.1378e-08 - accuracy: 1.0000
# Epoch 15/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.0005e-08 - accuracy: 1.0000 - val_loss: 0.1657 - val_accuracy: 0.7912
# Epoch 16/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.0104e-08 - accuracy: 1.0000 - val_loss: 0.1652 - val_accuracy: 0.7912
# Epoch 17/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0254e-08 - accuracy: 1.0000 - val_loss: 0.1603 - val_accuracy: 0.8048
# Epoch 18/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0464e-08 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.8121
# Epoch 19/25
# 96/96 [==============================] - 3s 27ms/step - loss: 4.9609e-08 - accuracy: 1.0000 - val_loss: 0.1635 - val_accuracy: 0.8048
# Epoch 20/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.5284e-08 - accuracy: 1.0000 - val_loss: 0.1620 - val_accuracy: 0.8048
# Epoch 21/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0915e-08 - accuracy: 1.0000 - val_loss: 0.1615 - val_accuracy: 0.8048
# Epoch 22/25
#  - ETA: 0s - loss: 5.0423e-08 - accuracy: 1.0000
# Epoch 23/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0014e-08 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 0.8048
# Epoch 24/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.0586e-08 - accuracy: 1.0000 - val_loss: 0.1583 - val_accuracy: 0.8048
# Epoch 25/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0300e-08 - accuracy: 1.0000 - val_loss: 0.1584 - val_accuracy: 0.8048
# test_TP: 88
# test_TN: 0
# test_FP: 0
# test_FN: 88
# * Accuracy on training set: 100.00%
# * Accuracy on validation set: 83.54%
# * Accuracy on test set: 50.00%
# ==========================================
#
#
# Epoch 1/25
# 96/96 [==============================] - 15s 37ms/step - loss: 5.1303e-08 - accuracy: 1.0000 - val_loss: 0.1583 - val_accuracy: 0.8048
# Epoch 2/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0315e-08 - accuracy: 1.0000 - val_loss: 0.1588 - val_accuracy: 0.8048
# Epoch 3/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.0176e-08 - accuracy: 1.0000 - val_loss: 0.1596 - val_accuracy: 0.8048
# Epoch 4/25
# 96/96 [==============================] - 3s 28ms/step - loss: 4.9887e-08 - accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 0.8048
# Epoch 5/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.0621e-08 - accuracy: 1.0000 - val_loss: 0.1608 - val_accuracy: 0.8048
# Epoch 6/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.1931e-08 - accuracy: 1.0000 - val_loss: 0.1618 - val_accuracy: 0.8048
# Epoch 7/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0592e-08 - accuracy: 1.0000 - val_loss: 0.1603 - val_accuracy: 0.8048
# Epoch 8/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.0609e-08 - accuracy: 1.0000 - val_loss: 0.1594 - val_accuracy: 0.8048
# Epoch 9/25
#  - ETA: 0s - loss: 4.9733e-08 - accuracy: 1.0000
# Epoch 10/25
#  - ETA: 1s - loss: 5.0853e-08 - accuracy: 1.0000
# Epoch 11/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0806e-08 - accuracy: 1.0000 - val_loss: 0.1584 - val_accuracy: 0.8048
# Epoch 12/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0146e-08 - accuracy: 1.0000 - val_loss: 0.1605 - val_accuracy: 0.8048
# Epoch 13/25
# 96/96 [==============================] - 3s 27ms/step - loss: 4.9984e-08 - accuracy: 1.0000 - val_loss: 0.1603 - val_accuracy: 0.8048
# Epoch 14/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0138e-08 - accuracy: 1.0000 - val_loss: 0.1620 - val_accuracy: 0.8048
# Epoch 15/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0515e-08 - accuracy: 1.0000 - val_loss: 0.1612 - val_accuracy: 0.8048
# Epoch 16/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0597e-08 - accuracy: 1.0000 - val_loss: 0.1582 - val_accuracy: 0.8048
# Epoch 17/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0235e-08 - accuracy: 1.0000 - val_loss: 0.1584 - val_accuracy: 0.8048
# Epoch 18/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0356e-08 - accuracy: 1.0000 - val_loss: 0.1588 - val_accuracy: 0.8048
# Epoch 19/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.1271e-08 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.8048
# Epoch 20/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0184e-08 - accuracy: 1.0000 - val_loss: 0.1617 - val_accuracy: 0.8048
# Epoch 21/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0403e-08 - accuracy: 1.0000 - val_loss: 0.1582 - val_accuracy: 0.8048
# Epoch 22/25
# 96/96 [==============================] - 3s 26ms/step - loss: 4.9683e-08 - accuracy: 1.0000 - val_loss: 0.1588 - val_accuracy: 0.8048
# Epoch 23/25
#  - ETA: 0s - loss: 5.0680e-08 - accuracy: 1.0000
# Epoch 24/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0125e-08 - accuracy: 1.0000 - val_loss: 0.1598 - val_accuracy: 0.8048
# Epoch 25/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0871e-08 - accuracy: 1.0000 - val_loss: 0.1603 - val_accuracy: 0.8048
# test_TP: 88
# test_TN: 0
# test_FP: 0
# test_FN: 88
# * Accuracy on training set: 100.00%
# * Accuracy on validation set: 83.54%
# * Accuracy on test set: 50.00%
# ==========================================
#
#
# Epoch 1/25
# 96/96 [==============================] - 15s 101ms/step - loss: 5.0047e-08 - accuracy: 1.0000 - val_loss: 0.1602 - val_accuracy: 0.8048
# Epoch 2/25
# 96/96 [==============================] - 3s 28ms/step - loss: 4.9966e-08 - accuracy: 1.0000 - val_loss: 0.1605 - val_accuracy: 0.8048
# Epoch 3/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0818e-08 - accuracy: 1.0000 - val_loss: 0.1671 - val_accuracy: 0.7912
# Epoch 4/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.0748e-08 - accuracy: 1.0000 - val_loss: 0.1653 - val_accuracy: 0.7912
# Epoch 5/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.0374e-08 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.8048
# Epoch 6/25
# 96/96 [==============================] - 3s 27ms/step - loss: 4.9909e-08 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.7912
# Epoch 7/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.1039e-08 - accuracy: 1.0000 - val_loss: 0.1912 - val_accuracy: 0.7331
# Epoch 8/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0630e-08 - accuracy: 1.0000 - val_loss: 0.1771 - val_accuracy: 0.7640
# Epoch 9/25
#  - ETA: 1s - loss: 5.0849e-08 - accuracy: 1.0000
# Epoch 10/25
# 96/96 [==============================] - 3s 27ms/step - loss: 4.9745e-08 - accuracy: 1.0000 - val_loss: 0.1681 - val_accuracy: 0.7912
# Epoch 11/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0954e-08 - accuracy: 1.0000 - val_loss: 0.1627 - val_accuracy: 0.8048
# Epoch 12/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.2184e-08 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.8048
# Epoch 13/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0298e-08 - accuracy: 1.0000 - val_loss: 0.1583 - val_accuracy: 0.8048
# Epoch 14/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0908e-08 - accuracy: 1.0000 - val_loss: 0.1593 - val_accuracy: 0.8048
# Epoch 15/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0871e-08 - accuracy: 1.0000 - val_loss: 0.1582 - val_accuracy: 0.8048
# Epoch 16/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0679e-08 - accuracy: 1.0000 - val_loss: 0.1589 - val_accuracy: 0.8048
# Epoch 17/25
# 96/96 [==============================] - 3s 26ms/step - loss: 4.9806e-08 - accuracy: 1.0000 - val_loss: 0.1589 - val_accuracy: 0.8048
# Epoch 18/25
#  - ETA: 1s - loss: 4.9649e-08 - accuracy: 1.0000
# Epoch 19/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0258e-08 - accuracy: 1.0000 - val_loss: 0.1583 - val_accuracy: 0.8048
# Epoch 20/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0577e-08 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.8048
# Epoch 21/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0034e-08 - accuracy: 1.0000 - val_loss: 0.1581 - val_accuracy: 0.8048
# Epoch 22/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.0134e-08 - accuracy: 1.0000 - val_loss: 0.1591 - val_accuracy: 0.8048
# Epoch 23/25
#  - ETA: 2s - loss: 5.0010e-08 - accuracy: 1.0000
# Epoch 24/25
#  - ETA: 1s - loss: 4.9481e-08 - accuracy: 1.0000
# Epoch 25/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0259e-08 - accuracy: 1.0000 - val_loss: 0.1596 - val_accuracy: 0.8048
# test_TP: 88
# test_TN: 0
# test_FP: 0
# test_FN: 88
# * Accuracy on training set: 100.00%
# * Accuracy on validation set: 83.54%
# * Accuracy on test set: 50.00%
# ==========================================
#
#
# Epoch 1/25
# 96/96 [==============================] - 12s 92ms/step - loss: 4.9898e-08 - accuracy: 1.0000 - val_loss: 0.1597 - val_accuracy: 0.8048
# Epoch 2/25
# 96/96 [==============================] - 3s 29ms/step - loss: 4.9854e-08 - accuracy: 1.0000 - val_loss: 0.1598 - val_accuracy: 0.8048
# Epoch 3/25
# 96/96 [==============================] - 3s 32ms/step - loss: 5.0268e-08 - accuracy: 1.0000 - val_loss: 0.1618 - val_accuracy: 0.8048
# Epoch 4/25
# 96/96 [==============================] - 3s 28ms/step - loss: 4.9662e-08 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 0.8048
# Epoch 5/25
# 96/96 [==============================] - 3s 28ms/step - loss: 5.0270e-08 - accuracy: 1.0000 - val_loss: 0.1634 - val_accuracy: 0.8048
# Epoch 6/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0507e-08 - accuracy: 1.0000 - val_loss: 0.1627 - val_accuracy: 0.8048
# Epoch 7/25
# 96/96 [==============================] - 3s 27ms/step - loss: 4.9794e-08 - accuracy: 1.0000 - val_loss: 0.1627 - val_accuracy: 0.8048
# Epoch 8/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.0640e-08 - accuracy: 1.0000 - val_loss: 0.1650 - val_accuracy: 0.7912
# Epoch 9/25
# 96/96 [==============================] - 2s 26ms/step - loss: 4.9759e-08 - accuracy: 1.0000 - val_loss: 0.1674 - val_accuracy: 0.7912
# Epoch 10/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.2501e-08 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.8048
# Epoch 11/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0368e-08 - accuracy: 1.0000 - val_loss: 0.1576 - val_accuracy: 0.8048
# Epoch 12/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0548e-08 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.8048
# Epoch 13/25
# 96/96 [==============================] - 3s 27ms/step - loss: 4.9865e-08 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.8048
# Epoch 14/25
# 96/96 [==============================] - 3s 26ms/step - loss: 4.9305e-08 - accuracy: 1.0000 - val_loss: 0.1579 - val_accuracy: 0.8048
# Epoch 15/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0323e-08 - accuracy: 1.0000 - val_loss: 0.1628 - val_accuracy: 0.8048
# Epoch 16/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.0422e-08 - accuracy: 1.0000 - val_loss: 0.1626 - val_accuracy: 0.8048
# Epoch 17/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0231e-08 - accuracy: 1.0000 - val_loss: 0.1620 - val_accuracy: 0.8048
# Epoch 18/25
# 96/96 [==============================] - 2s 26ms/step - loss: 5.0291e-08 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 0.8048
# Epoch 19/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0989e-08 - accuracy: 1.0000 - val_loss: 0.1707 - val_accuracy: 0.7912
# Epoch 20/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0184e-08 - accuracy: 1.0000 - val_loss: 0.1692 - val_accuracy: 0.7912
# Epoch 21/25
# 96/96 [==============================] - 3s 26ms/step - loss: 4.9953e-08 - accuracy: 1.0000 - val_loss: 0.1690 - val_accuracy: 0.7912
# Epoch 22/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0272e-08 - accuracy: 1.0000 - val_loss: 0.1670 - val_accuracy: 0.7912
# Epoch 23/25
# 96/96 [==============================] - 3s 27ms/step - loss: 4.9847e-08 - accuracy: 1.0000 - val_loss: 0.1653 - val_accuracy: 0.7912
# Epoch 24/25
# 96/96 [==============================] - 3s 27ms/step - loss: 5.0424e-08 - accuracy: 1.0000 - val_loss: 0.1632 - val_accuracy: 0.8048
# Epoch 25/25
# 96/96 [==============================] - 3s 26ms/step - loss: 5.0096e-08 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.7912
# test_TP: 89
# test_TN: 0
# test_FP: 0
# test_FN: 87
# * Accuracy on training set: 100.00%
# * Accuracy on validation set: 82.28%
# * Accuracy on test set: 50.57%
# ==========================================
